# %% [markdown]
# ## Welcome to the Perceptron!
#
# In this section, we will explore the **perceptron**—the foundational building block of all artificial neural networks. The code below sets up the machinery needed to build, train, and visualize a simple artificial neuron using Keras (a popular deep learning library).
#
# Here is a quick breakdown of what this code does:
#
# 1. **Builds the Brain:** The `buildModel()` function creates a true perceptron: a single mathematical node (a `Dense` layer) combined with a `hard_sigmoid` activation. This mimics the classic "all-or-nothing" step function used in the very first neural networks.
#
# 2. **Creates Visualization Tools:** It defines two helper functions (`plotHistory` and `plotDecision`) so you can visually track *how fast* the model is learning over time and *where* it draws its decision boundary to separate data points.
#
# 3. **Prepares Historical Benchmarks:** It constructs several small datasets representing fundamental Boolean logic gates (NOT, AND, OR, XOR). These simple rules are the historical benchmark tests used to prove whether a machine learning model actually works.
#
# 4. **Executes the First Training Run:** Finally, it initializes a 1D and a 2D perceptron and begins training the 1D model to learn the basic "NOT" logic gate, using an optimizer (Adam) to adjust its weights until it finds the correct answer.
#
# Run this cell to initialize our environment, and let's start teaching a machine to learn!

# %%
# Only run this cell after downloading and selecting your kernel
# !pip install keras tensorflow matplotlib numpy pydot graphviz
# Out:
# Requirement already satisfied: keras in c:\users\codeh\471book\jnb_env\lib\site-packages (3.12.2)
# Requirement already satisfied: tensorflow in c:\users\codeh\471book\jnb_env\lib\site-packages (2.21.0)
# Requirement already satisfied: matplotlib in c:\users\codeh\471book\jnb_env\lib\site-packages (3.10.9)
# Requirement already satisfied: numpy in c:\users\codeh\471book\jnb_env\lib\site-packages (2.2.6)
# Requirement already satisfied: pydot in c:\users\codeh\471book\jnb_env\lib\site-packages (4.0.1)
# Collecting graphviz
#   Downloading graphviz-0.21-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#      ---------------------------------------- 47.3/47.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: optree in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: rich in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: packaging in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (26.2)
# Requirement already satisfied: absl-py in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (2.4.0)
# Requirement already satisfied: ml-dtypes in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: h5py in c:\users\codeh\471book\jnb_env\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\codeh\471book\jnb_env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\codeh\471book\jnb_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\codeh\471book\jnb_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\codeh\471book\jnb_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\codeh\471book\jnb_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\codeh\471book\jnb_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\codeh\471book\jnb_env\lib\site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\codeh\471book\jnb_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.21
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam
from keras.utils import plot_model
import matplotlib.pyplot as plt
import numpy as np

###############################################################################
# Function Definitions
###############################################################################

##################################
# 1. Build Perceptrons
##################################
def buildModel(dim):
    model = Sequential()
    model.add(Dense(1, input_dim=dim))
    model.add(Activation('hard_sigmoid'))
    return model
    
   
##################################
# 3. History Plotting
##################################
def plotHistory(history, name):
    
    # # History Data
    # print(history.history.keys())
    # print(history.history['accuracy'])
    # print(history.history['val_accuracy'])
    # print(history.history['loss'])
    # print(history.history['val_loss'])
    
    # Accuracy Plot
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.title('Accuracy for %s' %(name))
    plt.legend(['Training', 'Validation'])
    plt.show()
    
    # Loss Plot
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.title('Loss for %s' %(name))
    plt.legend(['Training', 'Validation'])
    plt.show()


def plotDecision(xMatrix, yMatrix, weights, model):
    # Plotting points
    x = np.array(xMatrix[:,0].T)
    x = x.flatten()
    
    y = np.array(xMatrix[:,1].T)
    y = y.flatten()
    
    colors = np.array(yMatrix.T)
    colors = colors.flatten()
    
    
    plt.scatter(x, y, c=colors, cmap=plt.cm.Paired)
    plt.colorbar()
    
    # Plotting decision regions
    x_min, x_max = x.min() - 0.1, x.max() + 0.1
    y_min, y_max = y.min() - 0.1, y.max() + 0.1
    
#    print(x_min,x_max,y_min,y_max)
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict_on_batch(np.c_[xx.ravel(), yy.ravel()]) 

    Z = Z.reshape(xx.shape)   
    plt.contour(xx, yy, Z, 1, cmap=plt.cm.Paired)
    
    plt.ylim([x_min,x_max])
#    plt.xlim([y_min,y_max])
    plt.show()



###############################################################################
# Main Body of Code
###############################################################################
np.random.seed(1)
##################################
# 1. Build Perceptrons
##################################
p1model = buildModel(1)
p2model = buildModel(2)

adam = Adam(learning_rate=0.05, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
p1model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
plot_model(p1model, show_shapes=True, show_layer_names=True)

p2model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
plot_model(p1model, show_shapes=True, show_layer_names=True)


##################################
# 2. Build Boolean Matrices
##################################
xOne = np.asmatrix('1; 0')
xTwo = np.asmatrix('1,1; 1,0; 0,1; 0,0')
yNot = np.asmatrix('0;1')
yOr = np.asmatrix('1;1;1;0')
yAnd = np.asmatrix('1;0;0;0')
yXOR = np.asmatrix('0;1;1;0')


#Validation matrices
xOneVal = np.asmatrix('1')
xTwoVal = np.asmatrix('1,1; 1,0')
yNotVal = np.asmatrix('0')
yOrVal = np.asmatrix('1;1')
yAndVal = np.asmatrix('1;0')
yXORVal = np.asmatrix('0;1')


##################################
# 3. Build Nut Matrices
##################################
xNut = np.asmatrix('2.2,1.4; 1.5,1; 0.6,0.5; 2.3,2.0; 1.3,1.5; 0.3,1')
xNutVal = np.asmatrix('2.2,1.4; 0.3,1')

yNut = np.asmatrix('0;0;0;1;1;1')
yNutVal = np.asmatrix('0;1')

##################################
# 4. Train NOT dataset
##################################
# Create a kares callback that will stop training when the validation loss stops improving.
es = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=1, mode='auto')

# Build the model and train it on the NOT dataset, using the validation data and the early stopping callback.
NOThistory = p1model.fit(xOne, yNot, validation_data=(xOneVal, yNotVal), epochs=2000, batch_size=1, verbose=1, callbacks=[es])

#XORHistory = p2model.fit(xTwo, yXOR, validation_data=(xTwoVal, yXORVal), epochs=2000, batch_size=1, verbose=1, callbacks=[es])
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# Epoch 1/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.0000e+00 - loss: 0.8934 - val_accuracy: 0.0000e+00 - val_loss: 1.0692
# Epoch 2/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.8795 - val_accuracy: 0.0000e+00 - val_loss: 1.0151
# Epoch 3/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.8478 - val_accuracy: 0.0000e+00 - val_loss: 0.9824
# Epoch 4/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0000e+00 - loss: 0.8318 - val_accuracy: 0.0000e+00 - val_loss: 0.9490
# Epoch 5/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0000e+00 - loss: 0.8263 - val_accuracy: 0.0000e+00 - val_loss: 0.9076
# Epoch 6/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0000e+00 - loss: 0.8004 - val_accuracy: 0.0000e+00 - val_loss: 0.8773
# Epoch 7/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0000e+00 - loss: 0.7954 - val_accuracy: 0.0000e+00 - val_loss: 0.8413
# Epoch 8/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0000e+00 - loss: 0.7725 - val_accuracy: 0.0000e+00 - val_loss: 0.8142
# Epoch 9/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0000e+00 - loss: 0.7601 - val_accuracy: 0.0000e+00 - val_loss: 0.7879
# Epoch 10/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0000e+00 - loss: 0.7554 - val_accuracy: 0.0000e+00 - val_loss: 0.7573
# Epoch 11/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0000e+00 - loss: 0.7424 - val_accuracy: 0.0000e+00 - val_loss: 0.7290
# Epoch 12/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0000e+00 - loss: 0.7301 - val_accuracy: 0.0000e+00 - val_loss: 0.7028
# Epoch 13/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0000e+00 - loss: 0.7130 - val_accuracy: 1.0000 - val_loss: 0.6828
# Epoch 14/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 0.7082 - val_accuracy: 1.0000 - val_loss: 0.6589
# Epoch 15/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 0.6973 - val_accuracy: 1.0000 - val_loss: 0.6367
# Epoch 16/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.6825 - val_accuracy: 1.0000 - val_loss: 0.6198
# Epoch 17/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.6732 - val_accuracy: 1.0000 - val_loss: 0.6032
# Epoch 18/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.6683 - val_accuracy: 1.0000 - val_loss: 0.5831
# Epoch 19/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.6548 - val_accuracy: 1.0000 - val_loss: 0.5680
# Epoch 20/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.6461 - val_accuracy: 1.0000 - val_loss: 0.5532
# Epoch 21/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 0.6411 - val_accuracy: 1.0000 - val_loss: 0.5350
# Epoch 22/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 0.6287 - val_accuracy: 1.0000 - val_loss: 0.5214
# Epoch 23/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.6205 - val_accuracy: 1.0000 - val_loss: 0.5081
# Epoch 24/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 0.6154 - val_accuracy: 1.0000 - val_loss: 0.4916
# Epoch 25/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.6068 - val_accuracy: 1.0000 - val_loss: 0.4761
# Epoch 26/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.5960 - val_accuracy: 1.0000 - val_loss: 0.4647
# Epoch 27/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.5907 - val_accuracy: 1.0000 - val_loss: 0.4502
# Epoch 28/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.5804 - val_accuracy: 1.0000 - val_loss: 0.4396
# Epoch 29/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.5750 - val_accuracy: 1.0000 - val_loss: 0.4259
# Epoch 30/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.5671 - val_accuracy: 1.0000 - val_loss: 0.4129
# Epoch 31/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.5578 - val_accuracy: 1.0000 - val_loss: 0.4036
# Epoch 32/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.5522 - val_accuracy: 1.0000 - val_loss: 0.3913
# Epoch 33/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.5447 - val_accuracy: 1.0000 - val_loss: 0.3795
# Epoch 34/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.5360 - val_accuracy: 1.0000 - val_loss: 0.3711
# Epoch 35/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5303 - val_accuracy: 1.0000 - val_loss: 0.3597
# Epoch 36/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.5231 - val_accuracy: 1.0000 - val_loss: 0.3489
# Epoch 37/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5150 - val_accuracy: 1.0000 - val_loss: 0.3412
# Epoch 38/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.5081 - val_accuracy: 1.0000 - val_loss: 0.3334
# Epoch 39/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.5013 - val_accuracy: 1.0000 - val_loss: 0.3255
# Epoch 40/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4945 - val_accuracy: 1.0000 - val_loss: 0.3174
# Epoch 41/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4878 - val_accuracy: 1.0000 - val_loss: 0.3093
# Epoch 42/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.4812 - val_accuracy: 1.0000 - val_loss: 0.3012
# Epoch 43/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4759 - val_accuracy: 1.0000 - val_loss: 0.2904
# Epoch 44/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4692 - val_accuracy: 1.0000 - val_loss: 0.2803
# Epoch 45/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4616 - val_accuracy: 1.0000 - val_loss: 0.2732
# Epoch 46/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4551 - val_accuracy: 1.0000 - val_loss: 0.2660
# Epoch 47/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4498 - val_accuracy: 1.0000 - val_loss: 0.2561
# Epoch 48/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4425 - val_accuracy: 1.0000 - val_loss: 0.2493
# Epoch 49/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.4362 - val_accuracy: 1.0000 - val_loss: 0.2424
# Epoch 50/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.4300 - val_accuracy: 1.0000 - val_loss: 0.2354
# Epoch 51/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4238 - val_accuracy: 1.0000 - val_loss: 0.2284
# Epoch 52/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.4188 - val_accuracy: 1.0000 - val_loss: 0.2189
# Epoch 53/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.4125 - val_accuracy: 1.0000 - val_loss: 0.2100
# Epoch 54/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.4057 - val_accuracy: 1.0000 - val_loss: 0.2038
# Epoch 55/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3997 - val_accuracy: 1.0000 - val_loss: 0.1975
# Epoch 56/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3938 - val_accuracy: 1.0000 - val_loss: 0.1912
# Epoch 57/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3879 - val_accuracy: 1.0000 - val_loss: 0.1847
# Epoch 58/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3821 - val_accuracy: 1.0000 - val_loss: 0.1783
# Epoch 59/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3763 - val_accuracy: 1.0000 - val_loss: 0.1718
# Epoch 60/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3705 - val_accuracy: 1.0000 - val_loss: 0.1653
# Epoch 61/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3648 - val_accuracy: 1.0000 - val_loss: 0.1589
# Epoch 62/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3601 - val_accuracy: 1.0000 - val_loss: 0.1502
# Epoch 63/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3543 - val_accuracy: 1.0000 - val_loss: 0.1420
# Epoch 64/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3486 - val_accuracy: 1.0000 - val_loss: 0.1343
# Epoch 65/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.3430 - val_accuracy: 1.0000 - val_loss: 0.1269
# Epoch 66/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.3374 - val_accuracy: 1.0000 - val_loss: 0.1198
# Epoch 67/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3319 - val_accuracy: 1.0000 - val_loss: 0.1129
# Epoch 68/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3263 - val_accuracy: 1.0000 - val_loss: 0.1084
# Epoch 69/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3211 - val_accuracy: 1.0000 - val_loss: 0.1015
# Epoch 70/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.3157 - val_accuracy: 1.0000 - val_loss: 0.0949
# Epoch 71/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.3104 - val_accuracy: 1.0000 - val_loss: 0.0885
# Epoch 72/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.3051 - val_accuracy: 1.0000 - val_loss: 0.0843
# Epoch 73/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2998 - val_accuracy: 1.0000 - val_loss: 0.0798
# Epoch 74/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2948 - val_accuracy: 1.0000 - val_loss: 0.0731
# Epoch 75/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2895 - val_accuracy: 1.0000 - val_loss: 0.0686
# Epoch 76/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2843 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 77/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2795 - val_accuracy: 1.0000 - val_loss: 0.0572
# Epoch 78/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2744 - val_accuracy: 1.0000 - val_loss: 0.0508
# Epoch 79/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2692 - val_accuracy: 1.0000 - val_loss: 0.0464
# Epoch 80/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2642 - val_accuracy: 1.0000 - val_loss: 0.0419
# Epoch 81/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.2592 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 82/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.2546 - val_accuracy: 1.0000 - val_loss: 0.0306
# Epoch 83/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2494 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 84/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.2449 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 85/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2397 - val_accuracy: 1.0000 - val_loss: 0.0153
# Epoch 86/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2352 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 87/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2304 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 88/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2255 - val_accuracy: 1.0000 - val_loss: 1.1921e-07
# Epoch 89/2000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.2211 - val_accuracy: 1.0000 - val_loss: 1.1921e-07
# Epoch 89: early stopping

# %%
##################################
# 5 Plot Results
##################################

plotHistory(NOThistory, 'Not')

score = p1model.evaluate(xOne, yNot, batch_size=2, verbose=1)
print("%s: %.2f" % (p1model.metrics_names[0], score[0]))
print("%s: %.2f%%" % (p1model.metrics_names[1], score[1]*100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.2221
# loss: 0.22
# compile_metrics: 100.00%
